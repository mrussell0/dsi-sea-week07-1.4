# %% [markdown]
# ## Today we are going to test your knowledge in SQL. Please refer to  http://www.w3schools.com/sql/ for any questions you might have over the material. Each question must be solved in only ONE SQL statement. No pandas or numpy operations may be used!
# ### These questions get progressively more difficult. Look through the website above and stackoverflow for hints on solving the more challenging problems.
# ### Unfortunately, Brad will only be able to give help on questions with difficulty 7 and higher. He apologizes for the inconvenience.

# %% [markdown]
# #### First create a connection to your postgresql database here

# %%
## Some of these questions asked to print the full query. 
## I have written the query as so, but shorted in the print so minimize scrolling

# %%
from sqlalchemy import create_engine
import pandas as pd
engine = create_engine('postgres://mfnyeqfz:zxzi25vFYOiloQ8ORKUo2-Oog5GgfZc2@elmer.db.elephantsql.com:5432/mfnyeqfz')
pd.read_sql("SELECT * FROM information_schema.tables;", engine)[:3]
# Out:
#   table_catalog table_schema          table_name  table_type  \
# 0      mfnyeqfz       public  pg_stat_statements        VIEW
# 1      mfnyeqfz       public        trump_tweets  BASE TABLE
# 2      mfnyeqfz       public        website_imdb  BASE TABLE
#
#   self_referencing_column_name reference_generation user_defined_type_catalog  \
# 0                         None                 None                      None
# 1                         None                 None                      None
# 2                         None                 None                      None
#
#   user_defined_type_schema user_defined_type_name is_insertable_into is_typed  \
# 0                     None                   None                 NO       NO
# 1                     None                   None                YES       NO
# 2                     None                   None                YES       NO
#
#   commit_action
# 0          None
# 1          None
# 2          None

# %% [markdown]
# #### Let's use the "website_imdb" table for our queries

# %% [markdown]
# ## Difficulty => 1

# %% [markdown]
# ### Print out all the drama movies

# %%
pd.read_sql("SELECT * FROM website_imdb WHERE genre = 'Drama'", engine)[:3]
# Out:
#      id                title  \
# 0  2740    Good Will Hunting
# 1  2731        All About Eve
# 2  2756  Fanny and Alexander
#
#                                               poster  \
# 0  http://ia.media-imdb.com/images/M/MV5BMTk0NjY0...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...
#
#                                                 plot  genre  year  imdbRating  \
# 0  Will Hunting, a janitor at M.I.T., has a gift ...  Drama  1997         8.3
# 1  An ingenue insinuates herself into the company...  Drama  1950         8.3
# 2  Two young Swedish children experience the many...  Drama  1982         8.1
#
#                            created     imdbID  \
# 0 2016-11-13 22:22:15.411467+00:00  tt0119217
# 1 2016-11-13 22:22:15.409350+00:00  tt0042192
# 2 2016-11-13 22:22:15.415531+00:00  tt0083922
#
#                                             awards  \
# 0  Won 2 Oscars. Another 20 wins & 53 nominations.
# 1  Won 6 Oscars. Another 16 wins & 17 nominations.
# 2  Won 4 Oscars. Another 19 wins & 10 nominations.
#
#                          ...                                     director  \
# 0                        ...                                 Gus Van Sant
# 1                        ...                         Joseph L. Mankiewicz
# 2                        ...                               Ingmar Bergman
#
#          gross imdbVotes                           language     rated  \
# 0  138339411.0    609983                            English         R
# 1      10177.0     84353                    English, French  APPROVED
# 2          NaN     43998  Swedish, German, Yiddish, English         R
#
#      released response runtime   type  \
# 0  1998-01-09     True     126  movie
# 1  1951-01-15     True     138  movie
# 2  1982-12-17     True     188  movie
#
#                                              writer
# 0                           Matt Damon, Ben Affleck
# 1  Joseph L. Mankiewicz (written for the screen by)
# 2                                    Ingmar Bergman
#
# [3 rows x 22 columns]

# %% [markdown]
# ### Print out all the movies with a director with 'C' or 'S' in their last names. Ignore any movies with multiple directors.

# %%
pd.read_sql("SELECT * FROM website_imdb WHERE (director LIKE '%% C%%' OR director LIKE '%% S%%') AND director NOT LIKE '%%,%%'", engine)
# Out:
#       id                               title  \
# 0   2740                   Good Will Hunting
# 1   2721                            Whiplash
# 2   2723             Raiders of the Lost Ark
# 3   2728                   The Wages of Fear
# 4   2735                    The Great Escape
# 5   2745                         City Lights
# 6   2753               It Happened One Night
# 7   2757                      The Terminator
# 8   2766                         Raging Bull
# 9   2775                     Andaz Apna Apna
# 10  2780                    Schindler's List
# 11  2788                        The Departed
# 12  2790                      Shutter Island
# 13  2793                  The Usual Suspects
# 14  2796                       The Gold Rush
# 15  2797           In the Name of the Father
# 16  2803                          Diabolique
# 17  2804                           Gladiator
# 18  2808             The Wolf of Wall Street
# 19  2809                               Alien
# 20  2811                             The Kid
# 21  2814                       Jurassic Park
# 22  2817                  The Great Dictator
# 23  2827                 Catch Me If You Can
# 24  2829        Mr. Smith Goes to Washington
# 25  2833                         The Martian
# 26  2851                             Platoon
# 27  2853                     The Sixth Sense
# 28  2855                              Aliens
# 29  2861            The Secret in Their Eyes
# 30  2862                        Blade Runner
# 31  2866                       The Godfather
# 32  2876                          Wild Tales
# 33  2879               It's a Wonderful Life
# 34  2881                          Casablanca
# 35  2888                      Apocalypse Now
# 36  2893  Indiana Jones and the Last Crusade
# 37  2907                           The Thing
# 38  2920                     The Deer Hunter
# 39  2921                              WALL·E
# 40  2922                        Modern Times
# 41  2926                          Goodfellas
# 42  2929                              Casino
# 43  2934                     Bicycle Thieves
# 44  2935              The Godfather: Part II
# 45  2946                                Jaws
# 46  2956          Terminator 2: Judgment Day
# 47  2963                 Saving Private Ryan
# 48  2969                         Taxi Driver
#
#                                                poster  \
# 0   http://ia.media-imdb.com/images/M/MV5BMTk0NjY0...
# 1   https://images-na.ssl-images-amazon.com/images...
# 2   https://images-na.ssl-images-amazon.com/images...
# 3   https://images-na.ssl-images-amazon.com/images...
# 4   https://images-na.ssl-images-amazon.com/images...
# 5   https://images-na.ssl-images-amazon.com/images...
# 6   https://images-na.ssl-images-amazon.com/images...
# 7   https://images-na.ssl-images-amazon.com/images...
# 8   https://images-na.ssl-images-amazon.com/images...
# 9   https://images-na.ssl-images-amazon.com/images...
# 10  https://images-na.ssl-images-amazon.com/images...
# 11  https://images-na.ssl-images-amazon.com/images...
# 12  https://images-na.ssl-images-amazon.com/images...
# 13  https://images-na.ssl-images-amazon.com/images...
# 14  https://images-na.ssl-images-amazon.com/images...
# 15  https://images-na.ssl-images-amazon.com/images...
# 16  https://images-na.ssl-images-amazon.com/images...
# 17  https://images-na.ssl-images-amazon.com/images...
# 18  https://images-na.ssl-images-amazon.com/images...
# 19  https://images-na.ssl-images-amazon.com/images...
# 20  https://images-na.ssl-images-amazon.com/images...
# 21  https://images-na.ssl-images-amazon.com/images...
# 22  https://images-na.ssl-images-amazon.com/images...
# 23  https://images-na.ssl-images-amazon.com/images...
# 24  https://images-na.ssl-images-amazon.com/images...
# 25  https://images-na.ssl-images-amazon.com/images...
# 26  https://images-na.ssl-images-amazon.com/images...
# 27  https://images-na.ssl-images-amazon.com/images...
# 28  https://images-na.ssl-images-amazon.com/images...
# 29  https://images-na.ssl-images-amazon.com/images...
# 30  https://images-na.ssl-images-amazon.com/images...
# 31  https://images-na.ssl-images-amazon.com/images...
# 32  https://images-na.ssl-images-amazon.com/images...
# 33  https://images-na.ssl-images-amazon.com/images...
# 34  https://images-na.ssl-images-amazon.com/images...
# 35  https://images-na.ssl-images-amazon.com/images...
# 36  https://images-na.ssl-images-amazon.com/images...
# 37  https://images-na.ssl-images-amazon.com/images...
# 38  https://images-na.ssl-images-amazon.com/images...
# 39  https://images-na.ssl-images-amazon.com/images...
# 40  https://images-na.ssl-images-amazon.com/images...
# 41  https://images-na.ssl-images-amazon.com/images...
# 42  https://images-na.ssl-images-amazon.com/images...
# 43  https://images-na.ssl-images-amazon.com/images...
# 44  https://images-na.ssl-images-amazon.com/images...
# 45  https://images-na.ssl-images-amazon.com/images...
# 46  https://images-na.ssl-images-amazon.com/images...
# 47  https://images-na.ssl-images-amazon.com/images...
# 48  https://images-na.ssl-images-amazon.com/images...
#
#                                                  plot  \
# 0   Will Hunting, a janitor at M.I.T., has a gift ...
# 1   A promising young drummer enrolls at a cut-thr...
# 2   Archaeologist and adventurer Indiana Jones is ...
# 3   In a decrepit South American village, men are ...
# 4   Allied P.O.W.s plan for several hundred of the...
# 5   With the aid of a wealthy erratic tippler, a d...
# 6   A spoiled heiress, running away from her famil...
# 7   A human-looking indestructible cyborg is sent ...
# 8   An emotionally self-destructive boxer's journe...
# 9   Two slackers competing for the affections of a...
# 10  In German-occupied Poland during World War II,...
# 11  An undercover cop and a mole in the police att...
# 12  In 1954, a U.S. marshal investigates the disap...
# 13  A sole survivor tells of the twisty events lea...
# 14  A prospector goes to the Klondike in search of...
# 15  A man's coerced confession to an IRA bombing h...
# 16  The wife of a cruel headmaster and his mistres...
# 17  When a Roman general is betrayed and his famil...
# 18  Based on the true story of Jordan Belfort, fro...
# 19  After a space merchant vessel perceives an unk...
# 20  The Tramp cares for an abandoned child, but ev...
# 21  During a preview tour, a theme park suffers a ...
# 22  Dictator Adenoid Hynkel tries to expand his em...
# 23  The true story of Frank Abagnale Jr. who, befo...
# 24  A naive man is appointed to fill a vacancy in ...
# 25  An astronaut becomes stranded on Mars after hi...
# 26  A young recruit in Vietnam faces a moral crisi...
# 27  A boy who communicates with spirits that don't...
# 28  The moon from Alien (1979) has been colonized,...
# 29  A retired legal counselor writes a novel hopin...
# 30  A blade runner must pursue and try to terminat...
# 31  The aging patriarch of an organized crime dyna...
# 32  Six short stories that explore the extremities...
# 33  An angel helps a compassionate but despairingl...
# 34  In Casablanca, Morocco in December 1941, a cyn...
# 35  During the Vietnam War, Captain Willard is sen...
# 36  When Dr. Henry Jones Sr. suddenly goes missing...
# 37  It's the first week of winter in 1982. An Amer...
# 38  An in-depth examination of the ways in which t...
# 39  In the distant future, a small waste-collectin...
# 40  The Tramp struggles to live in modern industri...
# 41  Henry Hill and his friends work their way up t...
# 42  Greed, deception, money, power, and murder occ...
# 43  Set in Post-WWII Italy, a working class man's ...
# 44  The early life and career of Vito Corleone in ...
# 45  When a gigantic great white shark begins to me...
# 46  A cyborg, identical to the one who failed to k...
# 47  Following the Normandy Landings, a group of U....
# 48  A mentally unstable Vietnam War veteran works ...
#
#                            genre  year  imdbRating  \
# 0                          Drama  1997         8.3
# 1                   Drama, Music  2014         8.5
# 2              Action, Adventure  1981         8.5
# 3     Adventure, Drama, Thriller  1953         8.2
# 4      Adventure, Drama, History  1963         8.3
# 5         Comedy, Drama, Romance  1931         8.6
# 6                Comedy, Romance  1934         8.2
# 7                 Action, Sci-Fi  1984         8.1
# 8        Biography, Drama, Sport  1980         8.3
# 9        Comedy, Family, Romance  1994         8.7
# 10     Biography, Drama, History  1993         8.9
# 11        Crime, Drama, Thriller  2006         8.5
# 12             Mystery, Thriller  2010         8.1
# 13         Crime, Drama, Mystery  1995         8.6
# 14      Adventure, Comedy, Drama  1925         8.2
# 15              Biography, Drama  1993         8.1
# 16          Crime, Drama, Horror  1955         8.1
# 17      Action, Adventure, Drama  2000         8.5
# 18      Biography, Comedy, Crime  2013         8.2
# 19                Horror, Sci-Fi  1979         8.5
# 20         Comedy, Drama, Family  1921         8.3
# 21   Adventure, Sci-Fi, Thriller  1993         8.1
# 22            Comedy, Drama, War  1940         8.5
# 23       Biography, Crime, Drama  2002         8.0
# 24                 Comedy, Drama  1939         8.2
# 25      Adventure, Drama, Sci-Fi  2015         8.0
# 26                    Drama, War  1986         8.1
# 27      Drama, Mystery, Thriller  1999         8.1
# 28     Action, Adventure, Sci-Fi  1986         8.4
# 29      Drama, Mystery, Thriller  2009         8.2
# 30              Sci-Fi, Thriller  1982         8.2
# 31                  Crime, Drama  1972         9.2
# 32       Comedy, Drama, Thriller  2014         8.1
# 33        Drama, Family, Fantasy  1946         8.6
# 34           Drama, Romance, War  1942         8.6
# 35                    Drama, War  1979         8.5
# 36    Action, Adventure, Fantasy  1989         8.3
# 37       Horror, Mystery, Sci-Fi  1982         8.2
# 38                    Drama, War  1978         8.2
# 39  Animation, Adventure, Family  2008         8.4
# 40         Comedy, Drama, Family  1936         8.6
# 41       Biography, Crime, Drama  1990         8.7
# 42       Biography, Crime, Drama  1995         8.2
# 43                         Drama  1948         8.3
# 44                  Crime, Drama  1974         9.0
# 45    Adventure, Drama, Thriller  1975         8.0
# 46      Action, Sci-Fi, Thriller  1991         8.5
# 47            Action, Drama, War  1998         8.6
# 48                  Crime, Drama  1976         8.3
#
#                             created     imdbID  \
# 0  2016-11-13 22:22:15.411467+00:00  tt0119217
# 1  2016-11-13 22:22:15.406729+00:00  tt2582802
# 2  2016-11-13 22:22:15.407288+00:00  tt0082971
# 3  2016-11-13 22:22:15.408588+00:00  tt0046268
# 4  2016-11-13 22:22:15.410302+00:00  tt0057115
# 5  2016-11-13 22:22:15.412713+00:00  tt0021749
# 6  2016-11-13 22:22:15.414721+00:00  tt0025316
# 7  2016-11-13 22:22:15.415818+00:00  tt0088247
# 8  2016-11-13 22:22:15.418049+00:00  tt0081398
# 9  2016-11-13 22:22:15.420554+00:00  tt0109117
# 10 2016-11-13 22:22:15.421784+00:00  tt0108052
# 11 2016-11-13 22:22:15.423743+00:00  tt0407887
# 12 2016-11-13 22:22:15.424258+00:00  tt1130884
# 13 2016-11-13 22:22:15.424977+00:00  tt0114814
# 14 2016-11-13 22:22:15.425830+00:00  tt0015864
# 15 2016-11-13 22:22:15.426108+00:00  tt0107207
# 16 2016-11-13 22:22:15.427680+00:00  tt0046911
# 17 2016-11-13 22:22:15.427911+00:00  tt0172495
# 18 2016-11-13 22:22:15.429045+00:00  tt0993846
# 19 2016-11-13 22:22:15.429291+00:00  tt0078748
# 20 2016-11-13 22:22:15.429819+00:00  tt0012349
# 21 2016-11-13 22:22:15.430830+00:00  tt0107290
# 22 2016-11-13 22:22:15.431809+00:00  tt0032553
# 23 2016-11-13 22:22:15.434388+00:00  tt0264464
# 24 2016-11-13 22:22:15.434860+00:00  tt0031679
# 25 2016-11-13 22:22:15.435865+00:00  tt3659388
# 26 2016-11-13 22:22:15.440389+00:00  tt0091763
# 27 2016-11-13 22:22:15.440879+00:00  tt0167404
# 28 2016-11-13 22:22:15.441353+00:00  tt0090605
# 29 2016-11-13 22:22:15.442846+00:00  tt1305806
# 30 2016-11-13 22:22:15.443180+00:00  tt0083658
# 31 2016-11-13 22:22:15.444258+00:00  tt0068646
# 32 2016-11-13 22:22:15.446774+00:00  tt3011894
# 33 2016-11-13 22:22:15.447560+00:00  tt0038650
# 34 2016-11-13 22:22:15.448040+00:00  tt0034583
# 35 2016-11-13 22:22:15.449895+00:00  tt0078788
# 36 2016-11-13 22:22:15.451182+00:00  tt0097576
# 37 2016-11-13 22:22:15.456187+00:00  tt0084787
# 38 2016-11-13 22:22:15.459388+00:00  tt0077416
# 39 2016-11-13 22:22:15.459650+00:00  tt0910970
# 40 2016-11-13 22:22:15.459916+00:00  tt0027977
# 41 2016-11-13 22:22:15.461052+00:00  tt0099685
# 42 2016-11-13 22:22:15.461856+00:00  tt0112641
# 43 2016-11-13 22:22:15.463235+00:00  tt0040522
# 44 2016-11-13 22:22:15.463769+00:00  tt0071562
# 45 2016-11-13 22:22:15.467739+00:00  tt0073195
# 46 2016-11-13 22:22:15.470105+00:00  tt0103064
# 47 2016-11-13 22:22:15.472043+00:00  tt0120815
# 48 2016-11-13 22:22:15.473865+00:00  tt0075314
#
#                                                awards  \
# 0     Won 2 Oscars. Another 20 wins & 53 nominations.
# 1    Won 3 Oscars. Another 87 wins & 131 nominations.
# 2     Won 4 Oscars. Another 30 wins & 23 nominations.
# 3             Won 1 BAFTA Film Award. Another 5 wins.
# 4   Nominated for 1 Oscar. Another 2 wins & 7 nomi...
# 5                                             3 wins.
# 6        Won 5 Oscars. Another 5 wins & 1 nomination.
# 7                             5 wins & 6 nominations.
# 8     Won 2 Oscars. Another 22 wins & 24 nominations.
# 9                                      4 nominations.
# 10    Won 7 Oscars. Another 71 wins & 33 nominations.
# 11   Won 4 Oscars. Another 90 wins & 123 nominations.
# 12                           8 wins & 59 nominations.
# 13    Won 2 Oscars. Another 32 wins & 16 nominations.
# 14  Nominated for 2 Oscars. Another 3 wins & 1 nom...
# 15  Nominated for 7 Oscars. Another 7 wins & 21 no...
# 16                                            4 wins.
# 17   Won 5 Oscars. Another 53 wins & 101 nominations.
# 18  Nominated for 5 Oscars. Another 36 wins & 155 ...
# 19     Won 1 Oscar. Another 16 wins & 19 nominations.
# 20                                             1 win.
# 21    Won 3 Oscars. Another 28 wins & 17 nominations.
# 22  Nominated for 5 Oscars. Another 5 wins & 1 nom...
# 23  Nominated for 2 Oscars. Another 11 wins & 39 n...
# 24      Won 1 Oscar. Another 4 wins & 11 nominations.
# 25  Nominated for 7 Oscars. Another 33 wins & 172 ...
# 26    Won 4 Oscars. Another 19 wins & 14 nominations.
# 27  Nominated for 6 Oscars. Another 32 wins & 47 n...
# 28    Won 2 Oscars. Another 17 wins & 22 nominations.
# 29     Won 1 Oscar. Another 51 wins & 39 nominations.
# 30  Nominated for 2 Oscars. Another 11 wins & 16 n...
# 31    Won 3 Oscars. Another 23 wins & 27 nominations.
# 32  Nominated for 1 Oscar. Another 44 wins & 52 no...
# 33  Nominated for 5 Oscars. Another 6 wins & 1 nom...
# 34      Won 3 Oscars. Another 4 wins & 8 nominations.
# 35    Won 2 Oscars. Another 18 wins & 32 nominations.
# 36      Won 1 Oscar. Another 6 wins & 20 nominations.
# 37                                     3 nominations.
# 38    Won 5 Oscars. Another 17 wins & 26 nominations.
# 39     Won 1 Oscar. Another 86 wins & 85 nominations.
# 40                             4 wins & 1 nomination.
# 41     Won 1 Oscar. Another 37 wins & 32 nominations.
# 42  Nominated for 1 Oscar. Another 3 wins & 9 nomi...
# 43            Nominated for 1 Oscar. Another 18 wins.
# 44    Won 6 Oscars. Another 10 wins & 20 nominations.
# 45    Won 3 Oscars. Another 10 wins & 16 nominations.
# 46    Won 4 Oscars. Another 21 wins & 22 nominations.
# 47    Won 5 Oscars. Another 74 wins & 74 nominations.
# 48  Nominated for 4 Oscars. Another 21 wins & 15 n...
#
#                           ...                                       director  \
# 0                         ...                                   Gus Van Sant
# 1                         ...                                Damien Chazelle
# 2                         ...                               Steven Spielberg
# 3                         ...                          Henri-Georges Clouzot
# 4                         ...                                   John Sturges
# 5                         ...                                Charles Chaplin
# 6                         ...                                    Frank Capra
# 7                         ...                                  James Cameron
# 8                         ...                                Martin Scorsese
# 9                         ...                              Rajkumar Santoshi
# 10                        ...                               Steven Spielberg
# 11                        ...                                Martin Scorsese
# 12                        ...                                Martin Scorsese
# 13                        ...                                   Bryan Singer
# 14                        ...                                Charles Chaplin
# 15                        ...                                   Jim Sheridan
# 16                        ...                          Henri-Georges Clouzot
# 17                        ...                                   Ridley Scott
# 18                        ...                                Martin Scorsese
# 19                        ...                                   Ridley Scott
# 20                        ...                                Charles Chaplin
# 21                        ...                               Steven Spielberg
# 22                        ...                                Charles Chaplin
# 23                        ...                               Steven Spielberg
# 24                        ...                                    Frank Capra
# 25                        ...                                   Ridley Scott
# 26                        ...                                   Oliver Stone
# 27                        ...                             M. Night Shyamalan
# 28                        ...                                  James Cameron
# 29                        ...                           Juan José Campanella
# 30                        ...                                   Ridley Scott
# 31                        ...                           Francis Ford Coppola
# 32                        ...                                 Damián Szifrón
# 33                        ...                                    Frank Capra
# 34                        ...                                 Michael Curtiz
# 35                        ...                           Francis Ford Coppola
# 36                        ...                               Steven Spielberg
# 37                        ...                                 John Carpenter
# 38                        ...                                 Michael Cimino
# 39                        ...                                 Andrew Stanton
# 40                        ...                                Charles Chaplin
# 41                        ...                                Martin Scorsese
# 42                        ...                                Martin Scorsese
# 43                        ...                               Vittorio De Sica
# 44                        ...                           Francis Ford Coppola
# 45                        ...                               Steven Spielberg
# 46                        ...                                  James Cameron
# 47                        ...                               Steven Spielberg
# 48                        ...                                Martin Scorsese
#
#           gross imdbVotes                                           language  \
# 0   138339411.0    609983                                            English
# 1    13092000.0    413720                                            English
# 2   242374454.0    671034   English, German, Hebrew, Spanish, Arabic, Nepali
# 3           NaN     35833  French, English, Spanish, German, Italian, Rus...
# 4           NaN    167926          English, German, French, Russian, Spanish
# 5           NaN    111118                                            English
# 6           NaN     65874                                            English
# 7    38400000.0    608647                                   English, Spanish
# 8       45250.0    238964                                            English
# 9           NaN     32255                                              Hindi
# 10   96067179.0    877500                    English, Hebrew, German, Polish
# 11  132373442.0    885411                                 English, Cantonese
# 12  127968405.0    805512                                    English, German
# 13   23272306.0    755193                English, Hungarian, Spanish, French
# 14          NaN     69196                                            English
# 15   25010410.0    112200                                            English
# 16          NaN     42879                                    French, English
# 17  187670866.0   1000080                                            English
# 18  116866727.0    804969                                    English, French
# 19   78900000.0    575751                                   English, Spanish
# 20    2500000.0     68817                                            English
# 21  356784000.0    627863                                   English, Spanish
# 22          NaN    140070                                 English, Esperanto
# 23  164435221.0    538606                                    English, French
# 24          NaN     78231                                            English
# 25  228430993.0    506335                                  English, Mandarin
# 26  137963328.0    294733                                English, Vietnamese
# 27  293501675.0    715562                            English, Latin, Spanish
# 28   85200000.0    496655                                            English
# 29   20167424.0    135037                                            Spanish
# 30   27000000.0    467167    English, German, Cantonese, Japanese, Hungarian
# 31  134821952.0   1177812                            English, Italian, Latin
# 32    3079012.0     95454                                            Spanish
# 33          NaN    279316                                            English
# 34          NaN    392074                   English, French, German, Italian
# 35   78800000.0    456235                        English, French, Vietnamese
# 36  197171806.0    522489                     English, German, Greek, Arabic
# 37   13782838.0    264307                                 English, Norwegian
# 38          NaN    235569               English, Russian, Vietnamese, French
# 39  223806889.0    735150                                            English
# 40     163245.0    147025                                            English
# 41   46836394.0    738291                                   English, Italian
# 42   42438300.0    339327                                            English
# 43     332930.0     96195                                            Italian
# 44   57300000.0    807734         English, Italian, Spanish, Latin, Sicilian
# 45  260000000.0    421114                                            English
# 46  204843350.0    754399                                   English, Spanish
# 47  216119491.0    897416                     English, French, German, Czech
# 48          NaN    515479                                   English, Spanish
#
#         rated    released response runtime   type  \
# 0           R  1998-01-09     True     126  movie
# 1           R  2014-10-15     True     107  movie
# 2          PG  1981-06-12     True     115  movie
# 3   NOT RATED  1955-02-16     True     131  movie
# 4    APPROVED  1963-07-04     True     172  movie
# 5      PASSED  1931-03-07     True      87  movie
# 6     UNRATED  1934-02-23     True     105  movie
# 7           R  1984-10-26     True     107  movie
# 8           R  1980-12-19     True     129  movie
# 9          PG  1994-11-04     True     160  movie
# 10          R  1994-02-04     True     195  movie
# 11          R  2006-10-06     True     151  movie
# 12          R  2010-02-19     True     138  movie
# 13          R  1995-09-15     True     106  movie
# 14  NOT RATED         nan     True      95  movie
# 15          R  1994-02-25     True     133  movie
# 16    UNRATED  1955-11-21     True     116  movie
# 17          R  2000-05-05     True     155  movie
# 18          R  2013-12-25     True     180  movie
# 19          R  1979-06-22     True     117  movie
# 20  NOT RATED  1921-02-06     True      68  movie
# 21      PG-13  1993-06-11     True     127  movie
# 22   APPROVED  1941-03-07     True     125  movie
# 23      PG-13  2002-12-25     True     141  movie
# 24  NOT RATED  1939-10-19     True     129  movie
# 25      PG-13  2015-10-02     True     144  movie
# 26          R  1987-02-06     True     120  movie
# 27      PG-13  1999-08-06     True     107  movie
# 28          R  1986-07-18     True     137  movie
# 29          R  2010-05-21     True     129  movie
# 30          R  1982-06-25     True     117  movie
# 31          R  1972-03-24     True     175  movie
# 32          R  2014-08-21     True     122  movie
# 33         PG  1947-01-07     True     130  movie
# 34         PG  1943-01-23     True     102  movie
# 35          R  1979-08-15     True     153  movie
# 36      PG-13  1989-05-24     True     127  movie
# 37          R  1982-06-25     True     109  movie
# 38          R  1979-02-23     True     183  movie
# 39          G  2008-06-27     True      98  movie
# 40          G  1936-02-25     True      87  movie
# 41          R  1990-09-21     True     146  movie
# 42          R  1995-11-22     True     178  movie
# 43  NOT RATED  1949-12-13     True      89  movie
# 44          R  1974-12-20     True     202  movie
# 45         PG  1975-06-20     True     124  movie
# 46          R  1991-07-03     True     137  movie
# 47          R  1998-07-24     True     169  movie
# 48          R  1976-02-08     True     113  movie
#
#                                                writer
# 0                             Matt Damon, Ben Affleck
# 1                                     Damien Chazelle
# 2   Lawrence Kasdan (screenplay), George Lucas (st...
# 3   Georges Arnaud (novel), Henri-Georges Clouzot ...
# 4   Paul Brickhill (book), James Clavell (screenpl...
# 5                                     Charles Chaplin
# 6   Robert Riskin (screen play), Samuel Hopkins Ad...
# 7   James Cameron, Gale Anne Hurd, William Wisher ...
# 8   Jake LaMotta (based on the book by), Joseph Ca...
# 9   Rajkumar Santoshi (dialogue), Rajkumar Santosh...
# 10  Thomas Keneally (book), Steven Zaillian (scree...
# 11  William Monahan (screenplay), Alan Mak, Felix ...
# 12  Laeta Kalogridis (screenplay), Dennis Lehane (...
# 13                              Christopher McQuarrie
# 14                                    Charles Chaplin
# 15  Gerry Conlon (autobiographical book "Proved In...
# 16  Pierre Boileau (novel), Thomas Narcejac (novel...
# 17  David Franzoni (story), David Franzoni (screen...
# 18  Terence Winter (screenplay), Jordan Belfort (b...
# 19  Dan O'Bannon (story), Ronald Shusett (story), ...
# 20                                    Charles Chaplin
# 21  Michael Crichton (novel), Michael Crichton (sc...
# 22                                    Charles Chaplin
# 23  Jeff Nathanson (screenplay), Frank Abagnale Jr...
# 24  Sidney Buchman (screen play), Lewis R. Foster ...
# 25        Drew Goddard (screenplay), Andy Weir (book)
# 26                                       Oliver Stone
# 27                                 M. Night Shyamalan
# 28  James Cameron (story), David Giler (story), Wa...
# 29  Eduardo Sacheri, Juan José Campanella, Eduardo...
# 30  Hampton Fancher (screenplay), David Webb Peopl...
# 31  Mario Puzo (screenplay), Francis Ford Coppola ...
# 32                                     Damián Szifrón
# 33  Frances Goodrich (screenplay), Albert Hackett ...
# 34  Julius J. Epstein (screenplay), Philip G. Epst...
# 35  John Milius, Francis Ford Coppola, Michael Her...
# 36  Jeffrey Boam (screenplay), George Lucas (story...
# 37  Bill Lancaster (screenplay), John W. Campbell ...
# 38  Michael Cimino (story), Deric Washburn (story)...
# 39  Andrew Stanton (original story by), Pete Docte...
# 40                                    Charles Chaplin
# 41  Nicholas Pileggi (book), Nicholas Pileggi (scr...
# 42  Nicholas Pileggi (book), Nicholas Pileggi (scr...
# 43  Cesare Zavattini (story), Luigi Bartolini (nov...
# 44  Francis Ford Coppola (screenplay), Mario Puzo ...
# 45  Peter Benchley (screenplay), Carl Gottlieb (sc...
# 46                  James Cameron, William Wisher Jr.
# 47                                       Robert Rodat
# 48                                      Paul Schrader
#
# [49 rows x 22 columns]

# %% [markdown]
# ## Difficulty => 3

# %% [markdown]
# ### Print out the gross of each director's highest grossing movie. Filter nan.

# %%
pd.read_sql("SELECT director, max(gross) FROM website_imdb WHERE gross <> 'NaN' "
            " group by director;", engine)[:3]
# Out:
#        director         max
# 0     Tony Kaye   6712241.0
# 1  Bryan Singer  23272306.0
# 2  Tom McCarthy  44988180.0

# %% [markdown]
# ### Print out the gross of each director's highest grossing movie. Order by gross desc. Filter nan.

# %%
pd.read_sql("SELECT director, max(gross) FROM website_imdb WHERE gross <> 'NaN' "
            " GROUP BY director ORDER BY max(gross) desc;", engine)[:3]
# Out:
#             director          max
# 0        J.J. Abrams  936627416.0
# 1  Christopher Nolan  533316061.0
# 2       George Lucas  460935665.0

# %% [markdown]
# ## Difficulty => 5

# %% [markdown]
# ### Print out the movie title, gross, and director of each director's highest grossing movie. Order by gross desc. Filter nan.

# %%
pd.read_sql("SELECT title, director, max(gross) FROM website_imdb WHERE gross <> 'NaN' GROUP BY title, director ORDER BY max(gross) DESC", engine)[:5]
# Out:
#                                 title                   director          max
# 0        Star Wars: The Force Awakens                J.J. Abrams  936627416.0
# 1                     The Dark Knight          Christopher Nolan  533316061.0
# 2  Star Wars: Episode IV - A New Hope               George Lucas  460935665.0
# 3               The Dark Knight Rises          Christopher Nolan  448130642.0
# 4                       The Lion King  Roger Allers, Rob Minkoff  422783777.0

# %% [markdown]
# ### Print out the movie title, rating, and director of each director's highest rated movie if that director has directed more than one movie. Order by rating desc. Filter nan.

# %%
pd.read_sql('SELECT  db1.title, db1."imdbRating",db1.director FROM website_imdb db1, '
            '(select director, max("imdbRating") as max_imdbrating from website_imdb '
            ' WHERE "imdbRating" <> \'NaN\' GROUP BY director HAVING count(director) > 1) AS db2 '
            ' WHERE db1.director = db2.director and max_imdbrating = db1."imdbRating"'
            'ORDER BY db1."imdbRating" DESC' 
            '', engine)[:5]
# Out:
#                             title  imdbRating              director
# 0        The Shawshank Redemption         9.3        Frank Darabont
# 1                   The Godfather         9.2  Francis Ford Coppola
# 2                 The Dark Knight         9.0     Christopher Nolan
# 3                    12 Angry Men         8.9          Sidney Lumet
# 4  The Good, the Bad and the Ugly         8.9          Sergio Leone

# %% [markdown]
# ## Difficuty => 7

# %% [markdown]
# ### Print out the released date, title, and the season (winter, spring, summer, fall) in which each movie was released. Let's assume for simplicity sake that seasons end at the end of each month instead of on the 21st.

# %%
pd.read_sql('SELECT released, title, '
                '( CASE '
                '  WHEN substring(released,6,2) in (\'12\', \'01\',\'02\') THEN \'winter\' '
                '  WHEN substring(released,6,2) in (\'03\', \'04\',\'05\') THEN \'spring\' '    
                '  WHEN substring(released,6,2) in (\'06\', \'07\',\'08\') THEN \'summer\' '
                '  WHEN substring(released,6,2) in (\'09\', \'10\',\'11\') THEN \'fall\' ' 
                '  ELSE NULL'
                '  END) AS season ' 
            'FROM website_imdb '
    '', engine)[:3]
# Out:
#      released              title  season
# 0  1996-02-23           La Haine  winter
# 1  1998-01-09  Good Will Hunting  winter
# 2  2014-10-15           Whiplash    fall

# %% [markdown]
# ### Print out the released date, title, and the relation to today's date (disregard year). If the movie came out before today's month, print 'before' in the relationship column. If the movie came out after todays month, print out 'after' in the relationship column. If the movie was released in the same month, but not the same day, print out 'close'. If the movie came out on today's day and month print 'match'

# %%
pd.read_sql('SELECT released, title, '
             '( CASE '
 '  WHEN EXTRACT(MONTH FROM to_date(released,\'YYYY-MM-DD\')) > EXTRACT(MONTH FROM current_date) THEN \'after\' '
 '  WHEN EXTRACT(MONTH FROM to_date(released,\'YYYY-MM-DD\')) < EXTRACT(MONTH FROM current_date) THEN \'before\' '
 '  WHEN (EXTRACT(MONTH FROM to_date(released,\'YYYY-MM-DD\')) = EXTRACT(MONTH FROM current_date)) '
 '  AND (EXTRACT(DAY FROM to_date(released,\'YYYY-MM-DD\')) <> EXTRACT(DAY FROM current_date)) THEN \'close\' ' 
 '  WHEN (EXTRACT(MONTH FROM to_date(released,\'YYYY-MM-DD\')) = EXTRACT(MONTH FROM current_date)) '
 '  AND (EXTRACT(DAY FROM to_date(released,\'YYYY-MM-DD\')) = EXTRACT(DAY FROM current_date)) THEN \'match\' ' 
            '  ELSE NULL'
                '  END) AS relationship ' 
            'FROM website_imdb where released <> \'nan\' '
    '', engine)[:5]
# Out:
#      released                    title relationship
# 0  1996-02-23                 La Haine       before
# 1  1998-01-09        Good Will Hunting       before
# 2  2014-10-15                 Whiplash       before
# 3  1956-11-19            Seven Samurai       before
# 4  1981-06-12  Raiders of the Lost Ark       before

# %% [markdown]
# ## Difficulty => 9

# %% [markdown]
# ### There is another table in my database called 'trump_tweets'. Print out all the times Trump has sent a tweet with a movie title in the text. The movie title must have a length greater than 1.

# %%
pd.read_sql('SELECT tweet.text, imdb.title FROM trump_tweets tweet '
            ' JOIN website_imdb imdb ON lower(tweet.text) LIKE \'%%\'||lower(imdb.title)||\'%%\' ' 
            'WHERE length(imdb.title) > 1 ', engine )[:10]
# Out:
#                                                 text        title
# 0  Another new poll. Thank you for your support! ...           Up
# 1  Great poll- Florida! Thank you! https://t.co/4...           Up
# 2  "@AshleyEdam: New CBS Poll shows defections fr...           Up
# 3  WOW, great new poll- New York! Thank you for y...           Up
# 4  Don't believe the @FoxNews Polls, they are jus...  The General
# 5  "@cmichaeld2004: Realistic Trump Poll Numbers ...          Ran
# 6  Why would anyone in Kentucky listen to failed ...          Ran
# 7  .@CNN poll just hit 49% for Trump. Interesting...           Up
# 8  The polls show that I picked up many Jeb Bush ...           Up
# 9  The just out USA Today National Poll, where I ...           Up

# %% [markdown]
# ### Print out a movie if it is included in the following groups:
# * Has the longest runtime
# * Is created by the director who has the most imdbvotes
# * Has been translated into more than 4 languages
# * Has won 2 Oscars

# %%
# print 'Longest runtime : '
# pd.read_sql('SELECT title, runtime FROM website_imdb WHERE runtime = (SELECT max(runtime) FROM website_imdb)', engine)
# Out:
# Longest runtime :
#                 title  runtime
# 0  Gangs of Wasseypur      320

# %%
# print 'Title with the most IMDB votes by director: '
# pd.read_sql('SELECT title FROM website_imdb WHERE director IN ' 
#             '(SELECT director FROM website_imdb GROUP BY director ORDER BY SUM("imdbVotes") DESC limit 1)'
#             '', engine)
# Out:
# Title with the most IMDB votes by director:
#                    title
# 0        The Dark Knight
# 1           The Prestige
# 2          Batman Begins
# 3  The Dark Knight Rises
# 4           Interstellar
# 5              Inception
# 6                Memento

# %%
#pd.read_sql('select title, language from website_imdb '
#            ' WHERE (length(language) - length(replace(language,\',\',\'\'))) > 3 ', engine)

# %%
#pd.read_sql('SELECT title, language FROM website_imdb', engine)[:10]
# Out:
#                           title  \
# 0                      La Haine
# 1             Good Will Hunting
# 2                      Whiplash
# 3                 Seven Samurai
# 4       Raiders of the Lost Ark
# 5  The Bridge on the River Kwai
# 6           Like Stars on Earth
# 7                  The Revenant
# 8              Infernal Affairs
# 9             The Wages of Fear
#
#                                             language
# 0                                             French
# 1                                            English
# 2                                            English
# 3                                           Japanese
# 4   English, German, Hebrew, Spanish, Arabic, Nepali
# 5                            English, Japanese, Thai
# 6                                     Hindi, English
# 7                            English, Pawnee, French
# 8                           Cantonese, English, Thai
# 9  French, English, Spanish, German, Italian, Rus...

# %%
#print "title has been available in 4 or more languages: "
#pd.read_sql('SELECT title, language FROM website_imdb '
#            'WHERE (length(language) - )
#            SELECT lanuage FROM website_imdb')

# %%
#pd.read_sql("SELECT title FROM website_imdb WHERE awards LIKE '%%2 Oscars%%';", engine)
#pd.read_sql("SELECT title FROM website_imdb WHERE awards LIKE '%%Oscars%%';", engine)

# %%
pd.read_sql("SELECT title FROM website_imdb WHERE runtime = (SELECT max(runtime) FROM website_imdb)"
            ' OR director IN (SELECT director FROM website_imdb GROUP BY director ORDER BY sum("imdbVotes") DESC limit 1) '
            " OR (length(language) - length(replace(language,\',\',\'\'))) > 3 OR awards LIKE '%%Oscars%%';", engine)[:5]
# Out:
#                           title
# 0             Good Will Hunting
# 1                      Whiplash
# 2                 Seven Samurai
# 3       Raiders of the Lost Ark
# 4  The Bridge on the River Kwai

# %% [markdown]
# ### Make sure each movie is printed out at most one time!

# %% [markdown]
# ## Good job on completing this assignment! You should now be ready for any SQL-based problem thrown at you in the future!
#
# #### If you haven't finished the assignment, scroll back up. This message isn't for you.
